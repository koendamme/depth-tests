# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def regular_breathing(x):
    return np.sin(.1*x), np.sin(.1*x[-1])

def deep_breathing(x, start_p):
    return 1.5*np.sin(.05*(x-))

# %%
x = np.linspace(0, 1000, num=1000)

breathing = np.sin(.09*x)
breathing[500:] *= 1.5
plt.plot(x, breathing)

plt.axvspan(0, int(500*.6), color='red', alpha=0.5)
plt.axvspan(int(500*.6), int(500*.8), color='green', alpha=0.5)
plt.axvspan(int(500*.8), 500, color='blue', alpha=0.5)

plt.axvspan(500, 500+int(500*.6), color='red', alpha=0.5)
plt.axvspan(500+int(500*.6), 500+int(500*.8), color='green', alpha=0.5)
plt.axvspan(500+int(500*.8), 1000, color='blue', alpha=0.5)
