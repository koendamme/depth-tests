# %%
import pandas as pd
from datetime import datetime
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
test1 = pd.read_pickle(os.path.join("C:", os.sep, "Users", "kjwdamme", "Desktop", "test1.pickle"))
test2 = pd.read_pickle(os.path.join("C:", os.sep, "Users", "kjwdamme", "Desktop", "test2.pickle"))
test3 = pd.read_pickle(os.path.join("C:", os.sep, "Users", "kjwdamme", "Desktop", "test3.pickle"))
test4 = pd.read_pickle(os.path.join("C:", os.sep, "Users", "kjwdamme", "Desktop", "test4.pickle"))

# %%
len(test4[0]), len(test4[1])
# Out:
# (1895, 1895)

# %%
t_0 = datetime.fromtimestamp(test1[1][5])
t_1 = datetime.fromtimestamp(test1[1][6])

# %%
delta = t_1 - t_0

# %%
delta.microseconds/1000
# Out:
# 63.282

# %%
1000000/800
# Out:
# 1250.0

# %%
data = np.array(test1[0])

plt.plot(np.mean(data, axis=1)[:100])

# %%
data.
